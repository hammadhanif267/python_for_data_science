# %% [markdown]
# # Time series analysis on the data International Airline passengers from 1940 to 1960

# %%
#!pip install statsmodels

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# load the data
df = pd.read_csv("AirPassengers.csv")
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.shape
# Out:
# (144, 2)

# %%
# plot this data to see trends and seasonality with seaborn
sns.lineplot(x="Month", y="#Passengers", data=df)
# Out:
# <Axes: xlabel='Month', ylabel='#Passengers'>

# %%
# decompose the data into trend, seasonality and residuals
decompose = seasonal_decompose(df["#Passengers"], model="multiplicative", period=12)
decompose.plot()

# %%
decompose.seasonal.plot()
# Out:
# <Axes: >

# %%
trend = decompose.trend
seasonal = decompose.seasonal
residual = decompose.resid

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.metrics import RootMeanSquaredError

# split the data into training and testing sets
train_size = int(len(df) * 0.8)
train = df[:train_size]
test = df[train_size:]

# define the number of lagged time steps to use as input features
n_lags = 12

# create the input and output data for the neural network
X_train = np.array([train["#Passengers"].values[i:i+n_lags] for i in range(len(train)-n_lags)])
y_train = np.array(train["#Passengers"].values[n_lags:])
X_test = np.array([test["#Passengers"].values[i:i+n_lags] for i in range(len(test)-n_lags)])
y_test = np.array(test["#Passengers"].values[n_lags:])

# create the neural network model
model = Sequential()
model.add(Dense(10, input_dim=n_lags, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam", metrics=[RootMeanSquaredError()])

# train the neural network model
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

# make predictions on the testing set using the trained model
predictions = model.predict(X_test)

# plot the actual and predicted values
plt.plot(test.index[-len(predictions):], test["#Passengers"].values[-len(predictions):], label="actual")
plt.plot(test.index[-len(predictions):], predictions, label="predicted")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 152432.3750 - root_mean_squared_error: 390.2377
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91713.3750 - root_mean_squared_error: 302.4933
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54820.8594 - root_mean_squared_error: 232.8978
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25924.7188 - root_mean_squared_error: 160.6246
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14201.2734 - root_mean_squared_error: 118.5099
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5646.6719 - root_mean_squared_error: 74.8885
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3229.7095 - root_mean_squared_error: 56.1218
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1592.5829 - root_mean_squared_error: 39.7731
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1095.9756 - root_mean_squared_error: 33.0752
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1030.5514 - root_mean_squared_error: 32.0425
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 877.4954 - root_mean_squared_error: 29.5761
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 948.0499 - root_mean_squared_error: 30.6844
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 841.2264 - root_mean_squared_error: 28.9661
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 999.6776 - root_mean_squared_error: 31.6013
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 991.2953 - root_mean_squared_error: 31.3864
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 930.6652 - root_mean_squared_error: 30.4546
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1012.4716 - root_mean_squared_error: 31.7977
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 924.2009 - root_mean_squared_error: 30.3551
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 815.0112 - root_mean_squared_error: 28.2961
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 988.6647 - root_mean_squared_error: 31.3948
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1056.0648 - root_mean_squared_error: 32.4462
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1032.8102 - root_mean_squared_error: 32.0948
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 855.6937 - root_mean_squared_error: 29.1047
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 874.8774 - root_mean_squared_error: 29.5410
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 928.0038 - root_mean_squared_error: 30.4237
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 874.1229 - root_mean_squared_error: 29.3010
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 972.6459 - root_mean_squared_error: 31.0594
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 823.1172 - root_mean_squared_error: 28.5555
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 981.4690 - root_mean_squared_error: 31.2790
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 972.7394 - root_mean_squared_error: 31.0940
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 843.4155 - root_mean_squared_error: 29.0126
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 919.7652 - root_mean_squared_error: 30.2896
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 868.0365 - root_mean_squared_error: 29.3250
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 835.0236 - root_mean_squared_error: 28.7173
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 960.0774 - root_mean_squared_error: 30.8106
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 871.1400 - root_mean_squared_error: 29.4879
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1080.1310 - root_mean_squared_error: 32.6773
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 987.5071 - root_mean_squared_error: 31.3766
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1168.8601 - root_mean_squared_error: 34.0251
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1038.2614 - root_mean_squared_error: 32.1199
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1040.3131 - root_mean_squared_error: 32.0616
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 714.5776 - root_mean_squared_error: 26.4599
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1073.2029 - root_mean_squared_error: 32.5330
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 790.0299 - root_mean_squared_error: 28.0126
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 876.4406 - root_mean_squared_error: 29.5896
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 875.6455 - root_mean_squared_error: 29.5802
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 785.3539 - root_mean_squared_error: 27.9378
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 944.0375 - root_mean_squared_error: 30.6571
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 837.2063 - root_mean_squared_error: 28.8913
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 767.4773 - root_mean_squared_error: 27.6349
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 797.7228 - root_mean_squared_error: 28.2015
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 925.4894 - root_mean_squared_error: 30.3969
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 733.2886 - root_mean_squared_error: 26.9404
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 903.8370 - root_mean_squared_error: 30.0238
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 797.2978 - root_mean_squared_error: 28.1326
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 863.0622 - root_mean_squared_error: 29.3503
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 955.4337 - root_mean_squared_error: 30.8066
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 770.7726 - root_mean_squared_error: 27.6290
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 858.7937 - root_mean_squared_error: 29.2871
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 843.7861 - root_mean_squared_error: 28.9282
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 871.9301 - root_mean_squared_error: 29.5023
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 797.7384 - root_mean_squared_error: 28.2351
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 870.0870 - root_mean_squared_error: 29.2325
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 898.7817 - root_mean_squared_error: 29.8692
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 843.9638 - root_mean_squared_error: 29.0072
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 850.3607 - root_mean_squared_error: 29.1348
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 831.2438 - root_mean_squared_error: 28.7777
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 694.3386 - root_mean_squared_error: 25.9641
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 691.3190 - root_mean_squared_error: 26.2391
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 754.7833 - root_mean_squared_error: 27.3986
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1023.6783 - root_mean_squared_error: 31.7417
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 850.1676 - root_mean_squared_error: 29.0727
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1032.6149 - root_mean_squared_error: 31.9157
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 800.1866 - root_mean_squared_error: 28.0671
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 709.6796 - root_mean_squared_error: 26.6018
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 773.8671 - root_mean_squared_error: 27.7158
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 720.3376 - root_mean_squared_error: 26.7622
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 697.1723 - root_mean_squared_error: 26.3690
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 894.5422 - root_mean_squared_error: 29.8325
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 648.8930 - root_mean_squared_error: 25.3128
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 612.7764 - root_mean_squared_error: 24.4613
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 786.2448 - root_mean_squared_error: 28.0141
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 841.9372 - root_mean_squared_error: 28.9539
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 815.2394 - root_mean_squared_error: 28.4956
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 734.0438 - root_mean_squared_error: 27.0760
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 761.1417 - root_mean_squared_error: 27.5418
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 651.9292 - root_mean_squared_error: 25.4945
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 727.9160 - root_mean_squared_error: 26.9485
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 708.2484 - root_mean_squared_error: 26.3975
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 710.1562 - root_mean_squared_error: 26.4736
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 796.1747 - root_mean_squared_error: 28.1193
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 572.7753 - root_mean_squared_error: 23.8114
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 704.4413 - root_mean_squared_error: 26.5088
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 780.4639 - root_mean_squared_error: 27.8442
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 800.4513 - root_mean_squared_error: 28.2577
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 781.0738 - root_mean_squared_error: 27.8766
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 789.3046 - root_mean_squared_error: 28.0673
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 640.0658 - root_mean_squared_error: 25.2572
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 712.9268 - root_mean_squared_error: 26.6283
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 742.2317 - root_mean_squared_error: 27.2179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
